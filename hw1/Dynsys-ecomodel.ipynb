# %% [markdown]
# # Dynamical systems modeling and metaprogramming in Julia

# %% [markdown]
# - This notebook demonstrates how to develop, simulate, and infer the parameters of differential equation models in Julia
# - It illustrates some examples of metaprogramming in Julia via hygenic macros in `Catalyst.jl`
# - This allows for the automation of the process of generating models, and many different models can thus be created from a single block of code

# %% [markdown]
# Set up the environment

# %%
using Catalyst 
using DifferentialEquations
using Plots

#using Turing 
#import SymPy

# %% [markdown]
# ## Part 1: many models from one

# %% [markdown]
# Define a reaction network using `Catalyst.jl`. The reaction rates are given first, followed by the associated reactions. In this example of an ecological model, fish (🐟) eat frogs (🐸), and frogs eat ants (🐜); regulated by feedback interactions. Below we'll generate and work with different models based on the same reaction network: using ODEs, SDEs, or stochastic jump processes.

# %%
ecomodel = @reaction_network begin
    α₁ * (1 - 0.01 * 🐜 - 0.05 * 🐸), 🐜 --> 2🐜
    α₂ * (1 - 0.1 * 🐟), 🐜 --> 🐸
    δ₁, 🐜 --> ∅
    δ₂, 🐸 --> 🐟
    δ₃, 🐟 --> ∅
end
p = (:α₁ => 0.2, :α₂ => 0.15, :δ₁ => 0.05, :δ₂ => 0.15, :δ₃ => 0.1)
# Out:
# (:α₁ => 0.2, :α₂ => 0.15, :δ₁ => 0.05, :δ₂ => 0.15, :δ₃ => 0.1)

# %%
odes = convert(ODESystem, ecomodel)
# Out:
# WARNING: both Symbolics and ModelingToolkit export "infimum"; uses of it in module Catalyst must be qualified
# WARNING: both Symbolics and ModelingToolkit export "supremum"; uses of it in module Catalyst must be qualified
# Model ##ReactionSystem#231 with 3 equations
# Unknowns (3):
#   🐜(t)
#   🐸(t)
#   🐟(t)
# Parameters (5):
#   α₁
#   α₂
#   δ₁
#   δ₂
# ⋮

# %% [markdown]
# To simulate the ODE model derived from this reaction network, define the necessary inputs (parameters, initial conditions, time span), convert the reaction network into an ODEProblem and simulate directly using `DifferentialEquations.jl`

# %%
using DifferentialEquations 

## Colors for plotting
cc = ["#835C3B" "#10DA05" "#05E9FF"] 

## Parameters [α₁ α₂ δ₁ δ₂ δ₃]
par  = (:α₁ => 0.2, :α₂ => 0.15, :δ₁ => 0.05, :δ₂ => 0.15, :δ₃ =>0.1)

## Initial conditions
u₀ = [:🐜 =>20., :🐸=>20., :🐟=>10.]

## time span for simulation 
tspan = (0., 50.) 

## create the ODE system
ds = ODEProblem(ecomodel, u₀, tspan, par)  

sol = solve(ds, Tsit5()) 

plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])

# %% [markdown]
# ## Even simpler example of Catalyst.jl for getting started

# %%
simplemodel = @reaction_network begin
    k₁, x --> y
    k₂, y --> z
end

pmap = (:k₁ => 1.0, :k₂ => 2.0)

reactions(simplemodel)
# Out:
# 2-element Vector{Reaction}:
#  k₁, x --> y
#  k₂, y --> z

# %%
rn = complete(simplemodel)
odesys = convert(ODESystem, rn) 

u₀map = [:x => 10., :y => 0., :z => 0.]
# Out:
# 3-element Vector{Pair{Symbol, Float64}}:
#  :x => 10.0
#  :y => 0.0
#  :z => 0.0

# %%
# time interval to solve on
tspan = (0., 10.)

# create the ODEProblem we want to solve
prob = ODEProblem(rn, u₀map, tspan, pmap)
# Out:
# ODEProblem with uType Vector{Float64} and tType Float64. In-place: true
# timespan: (0.0, 10.0)
# u0: 3-element Vector{Float64}:
#  10.0
#   0.0
#   0.0

# %%
sol = solve(prob, Tsit5())
plot(sol, vars=(0,1)) 
plot!(sol, vars=(0,2))
# Out:
# ┌ Warning: To maintain consistency with solution indexing, keyword argument vars will be removed in a future version. Please use keyword argument idxs instead.
# │   caller = ip:0x0
# └ @ Core :-1

# %% [markdown]
# ### You can also define a diffeq model just using a function

# %% [markdown]
# For more info see: https://docs.sciml.ai/DiffEqDocs/stable/getting_started/

# %%
function newecomodel!(du, u, p, t) 
    α₁, α₂, δ₁, δ₂, δ₃, g₁, g₂, g₃ = p 
    
    du[1] = α₁*u[1]*(1 - g₁*u[1] - g₂*u[2]) - α₂*u[1]*(1-0.1*u[3]) - δ₁*u[1]
    du[2] = α₂*u[1]*(1 - g₃*u[3]) - δ₂*u[2] 
    du[3] = δ₂*u[2] - δ₃*u[3] 
end
# Out:
# newecomodel! (generic function with 1 method)

# %%
## Then define param and IC using array (not dict)

## Parameters [α₁ α₂ δ₁ δ₂ δ₃]
p = (0.2, 0.15, 0.05, 0.15, 0.1, 0.01, 0.05, 0.1)

## Initial conditions
u₀ = [20., 20., 10.]

## time span for simulation 
tspan = (0., 50.)

ds = ODEProblem(newecomodel!, u₀, tspan, p)
sol = solve(ds, Tsit5()) 

plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])

# %% [markdown]
# #### Stochastic dynamics => updates to syntax required...
# https://docs.sciml.ai/Catalyst/stable/introduction_to_catalyst/introduction_to_catalyst/

# %% [markdown]
# To simulate a stochastic differential equation (SDE) model from the same reaction network, using the same inputs as for the ODE model, we can directly declare the model with no new definitions. NB we assume Brownian noise in this example, other noise models can be substituted (e.g. by modifying the $g$ of the SDE)

# %% [markdown]
# $$
#  du = f(u,p,t)dt + g(u,p,t)dW.
# $$

# %%
stoch_ds = SDEProblem(ecomodel, u₀, tspan, p) 

dt = 1//2^(4)
sol = solve(stoch_ds, EM(), dt=dt)
plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])
# Out:
# ArgumentError: The variable-value mapping must be a Dict.
#
#
#
# Stacktrace:
#
#   [1] todict(d::NTuple{8, Float64})
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\utils.jl:66
#
#   [2] MTKParameters(sys::SDESystem, p::NTuple{8, Float64}, u0::Vector{Float64}; tofloat::Bool, use_union::Bool, t0::Nothing)
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\parameter_buffer.jl:45
#
#   [3] process_DEProblem(constructor::Type, sys::SDESystem, u0map::Vector{Float64}, parammap::NTuple{8, Float64}; implicit_dae::Bool, du0map::Nothing, version::Nothing, tgrad::Bool, jac::Bool, checkbounds::Bool, sparse::Bool, simplify::Bool, linenumbers::Bool, parallel::Symbolics.SerialForm, eval_expression::Bool, eval_module::Module, use_union::Bool, tofloat::Bool, symbolic_u0::Bool, u0_constructor::typeof(identity), guesses::Dict{Any, Any}, t::Nothing, warn_initialize_determined::Bool, build_initializeprob::Bool, initialization_eqs::Vector{Any}, fully_determined::Bool, check_units::Bool, kwargs::@Kwargs{check_length::Bool, noise_rate_prototype::Matrix{Float64}})
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\diffeqs\abstractodesystem.jl:845
#
#   [4] process_DEProblem
#
#     @ C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\diffeqs\abstractodesystem.jl:766 [inlined]
#
#   [5] (SDEProblem{true, SciMLBase.AutoSpecialize})(sys::SDESystem, u0map::Vector{Float64}, tspan::Tuple{Float64, Float64}, parammap::NTuple{8, Float64}; sparsenoise::Nothing, check_length::Bool, callback::Nothing, kwargs::@Kwargs{noise_rate_prototype::Matrix{Float64}})
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\diffeqs\sdesystem.jl:650
#
#   [6] (SDEProblem{true})(::SDESystem, ::Vector{Float64}, ::Vararg{Any}; kwargs::@Kwargs{check_length::Bool, noise_rate_prototype::Matrix{Float64}})
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\diffeqs\sdesystem.jl:705
#
#   [7] SDEProblem(::SDESystem, ::Vector{Float64}, ::Vararg{Any}; kwargs::@Kwargs{check_length::Bool, noise_rate_prototype::Matrix{Float64}})
#
#     @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\diffeqs\sdesystem.jl:694
#
#   [8] SDEProblem(::ReactionSystem{Catalyst.NetworkProperties{Int64, SymbolicUtils.BasicSymbolic{Real}}}, ::Vector{Float64}, ::Tuple{Float64, Float64}, ::NTuple{8, Float64}; name::Symbol, combinatoric_ratelaws::Bool, include_zero_odes::Bool, checks::Bool, check_length::Bool, remove_conserved::Bool, remove_conserved_warn::Bool, structural_simplify::Bool, kwargs::@Kwargs{})
#
#     @ Catalyst C:\Users\lexis\.julia\packages\Catalyst\Dgrwf\src\reactionsystem_conversions.jl:768
#
#   [9] SDEProblem(::ReactionSystem{Catalyst.NetworkProperties{Int64, SymbolicUtils.BasicSymbolic{Real}}}, ::Vector{Float64}, ::Tuple{Float64, Float64}, ::NTuple{8, Float64})
#
#     @ Catalyst C:\Users\lexis\.julia\packages\Catalyst\Dgrwf\src\reactionsystem_conversions.jl:748
#
#  [10] top-level scope
#
#     @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X33sZmlsZQ==.jl:1

# %% [markdown]
# To perform simulations of the discrete-time stochastic process associated with this reaction network, we can define a discrete problem and simulate it using SSA (Stochastic Simulation Algorithm), also known as the direct Gillespie algorithm.

# %%
ds_discrete = DiscreteProblem(ecomodel, [20,20,10], tspan, p)
jump_ds = JumpProblem(ecomodel, ds_discrete, Direct())

sol = solve(jump_ds, SSAStepper())
plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])
# Out:
# ArgumentError: The variable-value mapping must be a Dict.
#
#
#
# Stacktrace:
#
#  [1] todict(d::NTuple{8, Float64})
#
#    @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\utils.jl:66
#
#  [2] MTKParameters(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, p::NTuple{8, Float64}, u0::Vector{Int64}; tofloat::Bool, use_union::Bool, t0::Nothing)
#
#    @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\parameter_buffer.jl:45
#
#  [3] MTKParameters(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, p::NTuple{8, Float64}, u0::Vector{Int64})
#
#    @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\parameter_buffer.jl:27
#
#  [4] DiscreteProblem(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, u0map::Vector{Int64}, tspan::Tuple{Float64, Float64}, parammap::NTuple{8, Float64}; use_union::Bool, eval_expression::Bool, eval_module::Module, kwargs::@Kwargs{})
#
#    @ ModelingToolkit C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\jumps\jumpsystem.jl:355
#
#  [5] DiscreteProblem
#
#    @ C:\Users\lexis\.julia\packages\ModelingToolkit\2KZCu\src\systems\jumps\jumpsystem.jl:337 [inlined]
#
#  [6] DiscreteProblem(::ReactionSystem{Catalyst.NetworkProperties{Int64, SymbolicUtils.BasicSymbolic{Real}}}, ::Vector{Int64}, ::Tuple{Float64, Float64}, ::NTuple{8, Float64}; name::Symbol, combinatoric_ratelaws::Bool, checks::Bool, kwargs::@Kwargs{})
#
#    @ Catalyst C:\Users\lexis\.julia\packages\Catalyst\Dgrwf\src\reactionsystem_conversions.jl:855
#
#  [7] DiscreteProblem(::ReactionSystem{Catalyst.NetworkProperties{Int64, SymbolicUtils.BasicSymbolic{Real}}}, ::Vector{Int64}, ::Tuple{Float64, Float64}, ::NTuple{8, Float64})
#
#    @ Catalyst C:\Users\lexis\.julia\packages\Catalyst\Dgrwf\src\reactionsystem_conversions.jl:846
#
#  [8] top-level scope
#
#    @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X35sZmlsZQ==.jl:1

# %% [markdown]
# ## Part 2: Steady states and their stability

# %% [markdown]
# Here we solve the ecological model defined above at steady state symbolically, and study the linear stability of its steady states via analysis of the Jacobian matrix.

# %%
## Using SymPy, we define the variables and parameters of the model
## and re-define the ODE system in terms of its RHS
🐜, 🐸, 🐟 = SymPy.@vars 🐜 🐸 🐟
α₁, α₂, δ₁, δ₂, δ₃, g₁, g₂, g₃ = SymPy.@vars α₁ α₂ δ₁ δ₂ δ₃ g₁ g₂ g₃

rhs = [α₁*🐜*(1 - g₁*🐜 - g₂*🐸) - α₂*🐜 - δ₁*🐜,
       α₂*🐜*(1 - g₃*🐟) - δ₂*🐸,
       δ₂*🐸 - δ₃*🐟]

fps = SymPy.solve(rhs, [🐜,🐸,🐟])
# Out:
# LoadError: UndefVarError: `SymPy` not defined
#
# in expression starting at c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X41sZmlsZQ==.jl:3

# %%
J = rhs.jacobian([🐜,🐸,🐟])
# Out:
# UndefVarError: `rhs` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X42sZmlsZQ==.jl:1

# %% [markdown]
# Using the analytical solutions found for the steady states (fixed points) of the model and of its Jacobian, we can directly solve the Jacobian at a given fixed point in terms of the model parameters. (The solution is one that we would not want to derive by hand.)

# %%
## Select a fixed point
nfp = 2

## Substitute fixed point values
J_fp = J.subs([(🐜,fps[nfp][1]),(🐸,fps[nfp][2]),(🐟,fps[nfp][3])])
# Out:
# UndefVarError: `J` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X44sZmlsZQ==.jl:5

# %% [markdown]
# Next, to analyze the linear stability of the fixed point at a point in parameter space, we substitute into the previous expression the chosen set of parameter values.

# %%
## Substitute parameter values 
par = [0.2, 0.5, 0.5, 0.1, 0.7, 0.1, 0.05, 0.02]
J_eval = J_fp.subs([(α₁,par[1]),(α₂,par[2]),(δ₁,par[3]),(δ₂,par[4]),(δ₃,par[5]),(g₁,par[6]),(g₂,par[7]),(g₃,par[8])])
# Out:
# UndefVarError: `J_fp` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X46sZmlsZQ==.jl:3

# %% [markdown]
# Then the fixed point is stable at this point in parameter space if and only if all of the eigenvalues of the Jacobian have negative real part. Here we check whether this fixed point is stable:

# %%
## Calculate eigenvalues 
eigs = J_eval.eigenvals()

## Find the stability of the fixed point 
is_stable = false
if maximum(real(collect(keys(eigs)))) < 0
    is_stable = true
end
is_stable
# Out:
# UndefVarError: `J_eval` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\lexis\USC Code\24-fall\qbio577\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X51sZmlsZQ==.jl:2

# %% [markdown]
# ## Part 3: Parameter inference with Turing.jl

# %% [markdown]
# Below is a demo of parameter inference of an ODE model. We use `Catalyst.jl` and `DifferentialEquations.jl` for model definitions and simulation, and `Turing.jl` for sampling and inference.

# %% [markdown]
# First, we simulate some data with added noise that we will use with which to fit the model.

# %%
## Parameter inference
using Turing 
x0_inf = [5.; 5.; 5.]
p_inf = [0.8; 0.3; 0.1; 0.5; 1.4]
tspan = (0.0, 50.0)

ds = ODEProblem(ecomodel, x0_inf, tspan, p_inf)

sol = solve(ds,Tsit5(),saveat=.9)
targetdata = Array(sol) + 0.6*randn(size(Array(sol)))

plot(sol, alpha = 0.5, lc=cc, labels=["Ants" "Frogs" "Fish"]); scatter!(sol.t, targetdata', color=cc, labels=["Ants" "Frogs" "Fish"], legend=true)

# %% [markdown]
# Now define the model for inference. We use truncated Normal priors for each of the rate constants and an inverse Gamma distribution as the prior distribution over the noise $\sigma$. We run MCMC chain using NUTS in Turing.jl using a likelihood that samples from a Normal distribution where the simulated model defines the mean at each time point and the variance is $\sigma$.

# %%
@model function fitmodel(data, ds)
    σ ~ InverseGamma(2, 3) 
    α₁ ~ truncated(Normal(1.0,1.0),0,3)
    α₂ ~ truncated(Normal(1.0,1.0),0,3)
    δ₁ ~ truncated(Normal(1.0,1.0),0,3)
    δ₂ ~ truncated(Normal(1.0,1.0),0,3)
    δ₃ ~ truncated(Normal(1.0,1.0),0,3)

    p = [α₁,α₂,δ₁,δ₂,δ₃]
    prob = remake(ds, p=p)
    predicted = solve(prob,Tsit5(),saveat=.9)

    for i = 1:length(predicted)
        data[:,i] ~ MvNormal(predicted[i], σ)
    end
end

model = fitmodel(targetdata, ds)
@time chain = mapreduce(c -> sample(model, NUTS(.7), 1000), chainscat, 1:4)
# Out:
# Sampling   0%|█                                         |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.0015625
# └ @ Turing.Inference C:\Users\lexis\.julia\packages\Turing\Bv30p\src\mcmc\hmc.jl:212
# Sampling   0%|█                                         |  ETA: 1:43:16
# Sampling   1%|█                                         |  ETA: 0:51:31
# Sampling   1%|█                                         |  ETA: 0:34:13
# Sampling   2%|█                                         |  ETA: 0:25:33
# Sampling   2%|█                                         |  ETA: 0:20:22
# Sampling   3%|██                                        |  ETA: 0:16:55
# Sampling   3%|██                                        |  ETA: 0:14:28
# Sampling   4%|██                                        |  ETA: 0:12:40
# Sampling   4%|██                                        |  ETA: 0:11:14
# Sampling   5%|██                                        |  ETA: 0:10:06
# Sampling   5%|███                                       |  ETA: 0:09:10
# Sampling   6%|███                                       |  ETA: 0:08:23
# Sampling   6%|███                                       |  ETA: 0:07:43
# Sampling   7%|███                                       |  ETA: 0:07:10
# Sampling   7%|███                                       |  ETA: 0:06:42
# Sampling   7%|████                                      |  ETA: 0:06:17
# Sampling   8%|████                                      |  ETA: 0:05:55
# Sampling   8%|████                                      |  ETA: 0:05:34
# Sampling   9%|████                                      |  ETA: 0:05:16
# Sampling   9%|████                                      |  ETA: 0:05:01
# Sampling  10%|█████                                     |  ETA: 0:04:46
# Sampling  10%|█████                                     |  ETA: 0:04:32
# Sampling  11%|█████                                     |  ETA: 0:04:20
# Sampling  11%|█████                                     |  ETA: 0:04:09
# Sampling  12%|█████                                     |  ETA: 0:03:59
# Sampling  12%|██████                                    |  ETA: 0:03:50
# Sampling  13%|██████                                    |  ETA: 0:03:41
# Sampling  13%|██████                                    |  ETA: 0:03:33
# Sampling  14%|██████                                    |  ETA: 0:03:26
# Sampling  14%|██████                                    |  ETA: 0:03:19
# Sampling  14%|███████                                   |  ETA: 0:03:12
# Sampling  15%|███████                                   |  ETA: 0:03:05
# Sampling  15%|███████                                   |  ETA: 0:02:59
# Sampling  16%|███████                                   |  ETA: 0:02:54
# Sampling  16%|███████                                   |  ETA: 0:02:49
# Sampling  17%|████████                                  |  ETA: 0:02:44
# Sampling  17%|████████                                  |  ETA: 0:02:39
# Sampling  18%|████████                                  |  ETA: 0:02:35
# Sampling  18%|████████                                  |  ETA: 0:02:30
# Sampling  19%|████████                                  |  ETA: 0:02:27
# Sampling  19%|█████████                                 |  ETA: 0:02:23
# Sampling  20%|█████████                                 |  ETA: 0:02:19
# Sampling  20%|█████████                                 |  ETA: 0:02:16
# Sampling  21%|█████████                                 |  ETA: 0:02:13
# Sampling  21%|█████████                                 |  ETA: 0:02:10
# Sampling  21%|██████████                                |  ETA: 0:02:07
# Sampling  22%|██████████                                |  ETA: 0:02:04
# Sampling  22%|██████████                                |  ETA: 0:02:01
# Sampling  23%|██████████                                |  ETA: 0:01:59
# Sampling  23%|██████████                                |  ETA: 0:01:56
# Sampling  24%|██████████                                |  ETA: 0:01:54
# Sampling  24%|███████████                               |  ETA: 0:01:51
# Sampling  25%|███████████                               |  ETA: 0:01:49
# Sampling  25%|███████████                               |  ETA: 0:01:46
# Sampling  26%|███████████                               |  ETA: 0:01:44
# Sampling  26%|███████████                               |  ETA: 0:01:42
# Sampling  27%|████████████                              |  ETA: 0:01:40
# Sampling  27%|████████████                              |  ETA: 0:01:38
# Sampling  28%|████████████                              |  ETA: 0:01:36
# Sampling  28%|████████████                              |  ETA: 0:01:34
# Sampling  28%|████████████                              |  ETA: 0:01:32
# Sampling  29%|█████████████                             |  ETA: 0:01:30
