# %% [markdown]
# # Dynamical systems modeling in Julia 2022

# %% [markdown]
# - This notebook builds upon the previous dynamical systems modeling tutorial in #julialang from [here](https://github.com/adamlmaclean/julia-dynsys-resources/blob/main/Dynsys-ecomodel.ipynb)
# - Where before we focused on `Catalyst.jl`, here we demo `ModelingToolkit.jl` as a symbolic-numerical modeling environment with great flexibility and potential
# - We also dip into `DiffEqFlux.jl`
# - See [https://mtk.sciml.ai/](https://mtk.sciml.ai/) for more

# %% [markdown]
# Set up the environment (running on v1.7.3)

# %% [markdown]
# this is the July 2022 version

# %%
import Pkg;
# Pkg.add("ModelingToolkit")
# Pkg.add("OrdinaryDiffEq")
Pkg.add("Makie")
Pkg.add("CairoMakie")
Pkg.add("GlobalSensitivity")
Pkg.add("Random")
# Out:
#    Resolving package versions...
#    Installed ImageIO ─────────────── v0.6.8
#    Installed OpenEXR ─────────────── v0.3.2
#    Installed TiffImages ──────────── v0.10.0
#    Installed AdaptivePredicates ──── v1.1.1
#    Installed EarCut_jll ──────────── v2.2.4+0
#    Installed JpegTurbo ───────────── v0.1.5
#    Installed Sixel ───────────────── v0.1.3
#    Installed PNGFiles ────────────── v0.4.3
#    Installed FileIO ──────────────── v1.16.3
#    Installed SignedDistanceFields ── v0.4.0
#    Installed Netpbm ──────────────── v1.1.1
#    Installed FilePaths ───────────── v0.8.3
#    Installed TriplotBase ─────────── v0.1.0
#    Installed SIMD ────────────────── v3.5.0
#    Installed RoundingEmulator ────── v0.2.1
#    Installed isoband_jll ─────────── v0.2.3+0
#    Installed ImageMetadata ───────── v0.9.9
#    Installed PkgVersion ──────────── v0.3.3
#    Installed FreeType ────────────── v4.1.1
#    Installed PolygonOps ──────────── v0.1.2
#    Installed QOI ─────────────────── v1.0.0
#    Installed PaddedViews ─────────── v0.5.12
#    Installed MathTeXEngine ───────── v0.6.1
#    Installed GridLayoutBase ──────── v0.11.0
#    Installed LazyModules ─────────── v0.3.1
#    Installed MosaicViews ─────────── v0.3.4
#    Installed Automa ──────────────── v1.0.4
#    Installed FreeTypeAbstraction ─── v0.10.3
#    Installed Isoband ─────────────── v0.1.1
#    Installed ImageCore ───────────── v0.10.2
#    Installed Imath_jll ───────────── v3.1.11+0
#    Installed Extents ─────────────── v0.1.4
#    Installed Packing ─────────────── v0.5.0
#    Installed ExactPredicates ─────── v2.2.8
#    Installed StackViews ──────────── v0.1.1
#    Installed GeoFormatTypes ──────── v0.4.2
#    Installed Animations ──────────── v0.4.1
#    Installed ColorBrewer ─────────── v0.4.0
#    Installed IntervalArithmetic ──── v0.22.15
#    Installed OpenEXR_jll ─────────── v3.2.4+0
#    Installed ImageBase ───────────── v0.1.7
#    Installed IndirectArrays ──────── v1.0.0
#    Installed GeometryBasics ──────── v0.4.11
#    Installed MakieCore ───────────── v0.8.6
#    Installed ShaderAbstractions ──── v0.4.1
#    Installed libsixel_jll ────────── v1.10.3+0
#    Installed ImageAxes ───────────── v0.6.11
#    Installed FilePathsBase ───────── v0.9.22
#    Installed CRlibm_jll ──────────── v1.0.1+0
#    Installed Observables ─────────── v0.5.5
#    Installed GeoInterface ────────── v1.3.6
#    Installed Makie ───────────────── v0.21.9
#    Installed DelaunayTriangulation ─ v1.2.0
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Project.toml`
#   [ee78f7c6] + Makie v0.21.9
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Manifest.toml`
#   [35492f91] + AdaptivePredicates v1.1.1
#   [27a7e980] + Animations v0.4.1
#   [67c07d97] + Automa v1.0.4
#   [a2cac450] + ColorBrewer v0.4.0
#   [927a84f5] + DelaunayTriangulation v1.2.0
#   [429591f6] + ExactPredicates v2.2.8
#   [411431e0] + Extents v0.1.4
#   [5789e2e9] + FileIO v1.16.3
#   [8fc22ac5] + FilePaths v0.8.3
#   [48062228] + FilePathsBase v0.9.22
#   [b38be410] + FreeType v4.1.1
#   [663a7486] + FreeTypeAbstraction v0.10.3
#   [68eda718] + GeoFormatTypes v0.4.2
#   [cf35fbd7] + GeoInterface v1.3.6
#   [5c1252a2] + GeometryBasics v0.4.11
#   [3955a311] + GridLayoutBase v0.11.0
#   [2803e5a7] + ImageAxes v0.6.11
#   [c817782e] + ImageBase v0.1.7
#   [a09fc81d] + ImageCore v0.10.2
#   [82e4d734] + ImageIO v0.6.8
#   [bc367c6b] + ImageMetadata v0.9.9
#   [9b13fd28] + IndirectArrays v1.0.0
#   [d1acc4aa] + IntervalArithmetic v0.22.15
#   [f1662d9f] + Isoband v0.1.1
#   [b835a17e] + JpegTurbo v0.1.5
#   [8cdb02fc] + LazyModules v0.3.1
#   [ee78f7c6] + Makie v0.21.9
#   [20f20a25] + MakieCore v0.8.6
#   [0a4f8689] + MathTeXEngine v0.6.1
#   [e94cdb99] + MosaicViews v0.3.4
#   [f09324ee] + Netpbm v1.1.1
#   [510215fc] + Observables v0.5.5
#   [52e1d378] + OpenEXR v0.3.2
#   [f57f5aa1] + PNGFiles v0.4.3
#   [19eb6ba3] + Packing v0.5.0
#   [5432bcbf] + PaddedViews v0.5.12
#   [eebad327] + PkgVersion v0.3.3
#   [647866c9] + PolygonOps v0.1.2
#   [4b34888f] + QOI v1.0.0
#   [5eaf0fd0] + RoundingEmulator v0.2.1
#   [fdea26ae] + SIMD v3.5.0
#   [65257c39] + ShaderAbstractions v0.4.1
#   [73760f76] + SignedDistanceFields v0.4.0
#   [45858cf5] + Sixel v0.1.3
#   [cae243ae] + StackViews v0.1.1
#   [731e570b] + TiffImages v0.10.0
#   [981d1d27] + TriplotBase v0.1.0
#   [4e9b3aee] + CRlibm_jll v1.0.1+0
#   [5ae413db] + EarCut_jll v2.2.4+0
#   [905a6f67] + Imath_jll v3.1.11+0
#   [18a262bb] + OpenEXR_jll v3.2.4+0
#   [9a68df92] + isoband_jll v0.2.3+0
#   [075b6546] + libsixel_jll v1.10.3+0
#   [8bf52ea8] + CRC32c
# Precompiling project...
#   ✓ GeoFormatTypes
#   ✓ FilePathsBase
#   ✓ PolygonOps
#   ✓ IndirectArrays
#   ✓ LazyModules
#   ✓ RoundingEmulator
#   ✓ Extents
#   ✓ Observables
#   ✓ TriplotBase
#   ✓ AdaptivePredicates
#   ✓ PkgVersion
#   ✓ isoband_jll
#   ✓ EarCut_jll
#   ✓ CRlibm_jll
#   ✓ PaddedViews
#   ✓ libsixel_jll
#   ✓ Imath_jll
#     PyCall Being precompiled by another process (pid: 4608, pidfile: C:\Users\lexis\.julia\compiled\v1.10\PyCall\GkzkC_ZzOQf.ji.pidfile)
#   ✓ StackViews
#   ✓ SignedDistanceFields
#   ✓ FilePathsBase → FilePathsBaseMmapExt
#   ✓ Isoband
#   ✓ Animations
#   ✓ FreeType
#   ✓ ColorBrewer
#   ✓ PyCall
#   ✓ GeoInterface
#   ✓ MosaicViews
#   ✓ OpenEXR_jll
#   ✓ FilePathsBase → FilePathsBaseTestExt
#   ✓ FileIO
#   ✓ FilePaths
#   ✓ IntervalArithmetic
#   ✓ QOI
#   ✓ SymPy
#   ✓ Plots → FileIOExt
#   ✓ OpenEXR
#   ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#   ✓ IntervalArithmetic → IntervalArithmeticRecipesBaseExt
#   ✓ IntervalArithmetic → IntervalArithmeticDiffRulesExt
#   ✓ IntervalArithmetic → IntervalArithmeticsIntervalSetsExt
#   ✓ GeometryBasics
#   ✓ SIMD
#   ✓ Automa
#   ✓ Packing
#   ✓ ShaderAbstractions
#   ✓ ExactPredicates
#   ✓ FreeTypeAbstraction
#   ✓ Plots → GeometryBasicsExt
#   ✓ MakieCore
#   ✓ GridLayoutBase
#   ✓ DelaunayTriangulation
#   ✓ Polynomials → PolynomialsMakieCoreExt
#   ✓ MathTeXEngine
#   ✓ ImageCore
#   ✓ JpegTurbo
#   ✓ ImageBase
#   ✓ Sixel
#   ✓ PNGFiles
#   ✓ ImageAxes
#   ✓ ImageMetadata
#   ✓ Netpbm
#   ✓ Roots → RootsSymPyExt
#   ✓ TiffImages
#   ✓ ImageIO
#   ✓ Makie
#   ✓ SciMLBase → SciMLBaseMakieExt
#   ✓ DomainSets → DomainSetsMakieExt
#   ✓ SciMLBase → SciMLBasePyCallExt
#   ✓ Symbolics → SymbolicsSymPyExt
#   69 dependencies successfully precompiled in 271 seconds. 603 already precompiled.
#   1 dependency had output during precompilation:
# ┌ Roots → RootsSymPyExt
# │  [ Info: Installing sympy via the Conda sympy package...
# │  [ Info: Running `conda install -y sympy` in root environment
# 39mChannels:
# 39m - conda-forge
# 39mPlatform: win-64
# 39mCollecting package metadata (repodata.json): ...working... done
# 39mSolving environment: ...working... done
# 39m
# 39m
# 39m==> WARNING: A newer version of conda exists. <==
# 39m    current version: 24.3.0
# 39m    latest version: 24.7.1
# 39m
# 39mPlease update conda by running
# 39m
# 39m    $ conda update -n base -c conda-forge conda
# 39m
# 39m
# 39m
# 39m## Package Plan ##
# 39m
# 39m  environment location: C:\Users\lexis\.julia\conda\3\x86_64
# 39m
# 39m  added / updated specs:
# 39m    - sympy
# 39m
# 39m
# 39mThe following packages will be downloaded:
# 39m
# 39m    package                    |            build
# 39m    ---------------------------|-----------------
# 39m    mpmath-1.3.0               |     pyhd8ed1ab_0         428 KB  conda-forge
# 39m    sympy-1.13.2               |     pyh04b8f61_3         4.4 MB  conda-forge
# 39m    ------------------------------------------------------------
# 39m                                           Total:         4.8 MB
# 39m
# 39mThe following NEW packages will be INSTALLED:
# 39m
# 39m  mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
# 39m  sympy              conda-forge/noarch::sympy-1.13.2-pyh04b8f61_3
# 39m
# 39m
# 39m
# 39mDownloading and Extracting Packages: ...working... done
# 39mPreparing transaction: ...working... done
# 39mVerifying transaction: ...working... done
# │  Executing transaction: ...working... done
# └
#    Resolving package versions...
#    Installed Graphics ─── v1.1.2
#    Installed CairoMakie ─ v0.12.9
#    Installed Cairo ────── v1.1.0
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Project.toml`
#   [13f3f980] + CairoMakie v0.12.9
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Manifest.toml`
#   [159f3aea] + Cairo v1.1.0
#   [13f3f980] + CairoMakie v0.12.9
#   [a2bd30eb] + Graphics v1.1.2
# Precompiling project...
#   ✓ IntervalArithmetic → IntervalArithmeticForwardDiffExt
#   ✓ Graphics
#   ✓ Cairo
# CairoMakie Waiting for background task / IO / timer.
# [pid 24580] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              0000019c815b1940->0000019c854b6d10
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   ✓ CairoMakie
#   ✓ Catalyst → CatalystCairoMakieExtension
#   5 dependencies successfully precompiled in 100 seconds. 671 already precompiled.
#   1 dependency had output during precompilation:
# ┌ CairoMakie
# │  [pid 24580] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              0000019c815b1940->0000019c854b6d10
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# └
#    Resolving package versions...
#    Installed Referenceables ─────── v0.1.3
#    Installed TaylorSeries ───────── v0.13.2
#    Installed MvNormalCDF ────────── v0.3.2
#    Installed ThreadsX ───────────── v0.1.12
#    Installed DelayEmbeddings ────── v2.7.4
#    Installed GlobalSensitivity ──── v2.7.0
#    Installed NearestNeighbors ───── v0.4.18
#    Installed StateSpaceSets ─────── v1.5.0
#    Installed QuasiMonteCarlo ────── v0.3.3
#    Installed Cubature_jll ───────── v1.0.5+0
#    Installed LatticeRules ───────── v0.0.1
#    Installed WilliamsonTransforms ─ v0.1.5
#    Installed Neighborhood ───────── v0.2.4
#    Installed Trapz ──────────────── v2.0.3
#    Installed Cubature ───────────── v1.5.1
#    Installed Wavelets ───────────── v0.10.0
#    Installed Copulas ────────────── v0.1.24
#    Installed ComplexityMeasures ─── v3.6.6
#    Installed Sobol ──────────────── v1.5.0
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Project.toml`
#   [af5da776] + GlobalSensitivity v2.7.0
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Manifest.toml`
#   [ab4b797d] + ComplexityMeasures v3.6.6
#   [ae264745] + Copulas v0.1.24
#   [667455a9] + Cubature v1.5.1
#   [5732040d] + DelayEmbeddings v2.7.4
#   [af5da776] + GlobalSensitivity v2.7.0
#   [73f95e8e] + LatticeRules v0.0.1
#   [37188c8d] + MvNormalCDF v0.3.2
#   [b8a86587] + NearestNeighbors v0.4.18
#   [645ca80c] + Neighborhood v0.2.4
#   [8a4e6c94] + QuasiMonteCarlo v0.3.3
#   [42d2dcc6] + Referenceables v0.1.3
#   [ed01d8cd] + Sobol v1.5.0
#   [40b095a5] + StateSpaceSets v1.5.0
# ⌅ [6aa5eb33] + TaylorSeries v0.13.2
#   [ac1d9e8a] + ThreadsX v0.1.12
#   [592b5752] + Trapz v2.0.3
#   [29a6e085] + Wavelets v0.10.0
#   [48feb556] + WilliamsonTransforms v0.1.5
#   [7bc98958] + Cubature_jll v1.0.5+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ LatticeRules
#   ✓ Trapz
#   ✓ Referenceables
#   ✓ Cubature_jll
#   ✓ Sobol
#   ✓ MvNormalCDF
#   ✓ NearestNeighbors
#   ✓ TaylorSeries
#   ✓ Transducers → TransducersReferenceablesExt
#   ✓ Cubature
#   ✓ Neighborhood
#   ✓ Wavelets
#   ✓ ThreadsX
#   ✓ QuasiMonteCarlo
#   ✓ WilliamsonTransforms
#   ✓ StateSpaceSets
#   ✓ QuasiMonteCarlo → QuasiMonteCarloDistributionsExt
#   ✓ DelayEmbeddings
#   ✓ ComplexityMeasures
#   ✗ Copulas
#   ✗ GlobalSensitivity
#   19 dependencies successfully precompiled in 40 seconds. 676 already precompiled.
#
# The following 1 direct dependency failed to precompile:
#
# GlobalSensitivity [af5da776-676b-467e-8baf-acd8249e4f0f]
#
# Failed to precompile GlobalSensitivity [af5da776-676b-467e-8baf-acd8249e4f0f] to "C:\\Users\\lexis\\.julia\\compiled\\v1.10\\GlobalSensitivity\\jl_7B.tmp".
# ERROR: LoadError: MethodError: no method matching isless(::TaylorSeries.Taylor1{Float64}, ::TaylorSeries.Taylor1{Float64})
#
# Closest candidates are:
#   isless(::Missing, ::Any)
#    @ Base missing.jl:87
#   isless(::Any, ::Missing)
#    @ Base missing.jl:88
#
# Stacktrace:
#   [1] max(x::TaylorSeries.Taylor1{Float64}, y::TaylorSeries.Taylor1{Float64})
#     @ Base .\operators.jl:476
#   [2] ϕ(G::Copulas.ClaytonGenerator{Float64}, t::TaylorSeries.Taylor1{Float64})
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Generator\UnivariateGenerator\ClaytonGenerator.jl:43
#   [3] ϕ⁽ᵏ⁾(G::Copulas.ClaytonGenerator{Float64}, k::Int64, t::Float64)
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Generator.jl:40
#   [4] ϕ⁽ᵏ⁾(C::Copulas.ClaytonCopula{2, Float64}, k::Int64, t::Float64)
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\ArchimedeanCopula.jl:54
#   [5] _logpdf(C::Copulas.ClaytonCopula{2, Float64}, u::Vector{Float64})
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\ArchimedeanCopula.jl:76
#   [6] logpdf
#     @ C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:263 [inlined]
#   [7] _pdf
#     @ C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:237 [inlined]
#   [8] pdf(d::Copulas.ClaytonCopula{2, Float64}, x::Vector{Float64})
#     @ Distributions C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:222
#   [9] macro expansion
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:150 [inlined]
#  [10] macro expansion
#     @ C:\Users\lexis\.julia\packages\PrecompileTools\L8A3n\src\workloads.jl:78 [inlined]
#  [11] macro expansion
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:119 [inlined]
#  [12] macro expansion
#     @ C:\Users\lexis\.julia\packages\PrecompileTools\L8A3n\src\workloads.jl:140 [inlined]
#  [13] top-level scope
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:116
#  [14] include
#     @ .\Base.jl:495 [inlined]
#  [15] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [16] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile Copulas [ae264745-0b69-425e-9d9d-cf662c5eec93] to "C:\\Users\\lexis\\.julia\\compiled\\v1.10\\Copulas\\jl_A83.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\lexis\.julia\packages\GlobalSensitivity\fxoe7\src\GlobalSensitivity.jl:1
# in expression starting at stdin:   Resolving package versions...
#     Updating `C:\Users\lexis\.julia\environments\v1.10\Project.toml`
#   [9a3f8284] + Random
#   No Changes to `C:\Users\lexis\.julia\environments\v1.10\Manifest.toml`

# %%
using ModelingToolkit, OrdinaryDiffEq
using Catalyst, Latexify
using Plots, Makie, CairoMakie
using GlobalSensitivity, Random
#using NonlinearSolve
# Out:
# ERROR: LoadError: MethodError: no method matching isless(::TaylorSeries.Taylor1{Float64}, ::TaylorSeries.Taylor1{Float64})
#
# Closest candidates are:
#   isless(::Missing, ::Any)
#    @ Base missing.jl:87
#   isless(::Any, ::Missing)
#    @ Base missing.jl:88
#
# Stacktrace:
#   [1] max(x::TaylorSeries.Taylor1{Float64}, y::TaylorSeries.Taylor1{Float64})
#     @ Base .\operators.jl:476
#   [2] ϕ(G::Copulas.ClaytonGenerator{Float64}, t::TaylorSeries.Taylor1{Float64})
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Generator\UnivariateGenerator\ClaytonGenerator.jl:43
#   [3] ϕ⁽ᵏ⁾(G::Copulas.ClaytonGenerator{Float64}, k::Int64, t::Float64)
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Generator.jl:40
#   [4] ϕ⁽ᵏ⁾(C::Copulas.ClaytonCopula{2, Float64}, k::Int64, t::Float64)
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\ArchimedeanCopula.jl:54
#   [5] _logpdf(C::Copulas.ClaytonCopula{2, Float64}, u::Vector{Float64})
#     @ Copulas C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\ArchimedeanCopula.jl:76
#   [6] logpdf
#     @ C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:263 [inlined]
#   [7] _pdf
#     @ C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:237 [inlined]
#   [8] pdf(d::Copulas.ClaytonCopula{2, Float64}, x::Vector{Float64})
#     @ Distributions C:\Users\lexis\.julia\packages\Distributions\nmUhn\src\common.jl:222
#   [9] macro expansion
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:150 [inlined]
#  [10] macro expansion
#     @ C:\Users\lexis\.julia\packages\PrecompileTools\L8A3n\src\workloads.jl:78 [inlined]
#  [11] macro expansion
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:119 [inlined]
#  [12] macro expansion
#     @ C:\Users\lexis\.julia\packages\PrecompileTools\L8A3n\src\workloads.jl:140 [inlined]
#  [13] top-level scope
#     @ C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:116
#  [14] include
#     @ .\Base.jl:495 [inlined]
#  [15] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [16] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\lexis\.julia\packages\Copulas\e7UMO\src\Copulas.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile Copulas [ae264745-0b69-425e-9d9d-cf662c5eec93] to "C:\\Users\\lexis\\.julia\\compiled\\v1.10\\Copulas\\jl_D6AD.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\lexis\.julia\packages\GlobalSensitivity\fxoe7\src\GlobalSensitivity.jl:1
# in expression starting at stdin:3
# Failed to precompile GlobalSensitivity [af5da776-676b-467e-8baf-acd8249e4f0f] to "C:\\Users\\lexis\\.julia\\compiled\\v1.10\\GlobalSensitivity\\jl_CE8C.tmp".
#
#
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base .\error.jl:35
#
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#
#     @ Base .\loading.jl:2468
#
#   [3] compilecache
#
#     @ .\loading.jl:2340 [inlined]
#
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#
#     @ Base .\loading.jl:1974
#
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#
#   [6] #mkpidlock#6
#
#     @ C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#
#     @ FileWatching.Pidfile C:\Users\lexis\.julia\juliaup\julia-1.10.4+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#
#   [8] #invokelatest#2
#
#     @ .\essentials.jl:894 [inlined]
#
#   [9] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#
#     @ Base .\loading.jl:2983
#
#  [11] maybe_cachefile_lock
#
#     @ .\loading.jl:2980 [inlined]
#
#  [12] _require(pkg::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1970
#
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1812
#
#  [14] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#  [15] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1803
#
#  [17] macro expansion
#
#     @ .\loading.jl:1790 [inlined]
#
#  [18] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#  [19] __require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1753
#
#  [20] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#  [21] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#  [22] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1746
#
#  [23] eval
#
#     @ .\boot.jl:385 [inlined]
#
#  [24] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2076
#
#  [25] #invokelatest#2
#
#     @ .\essentials.jl:892 [inlined]
#
#  [26] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#  [27] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#  [28] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\packages\VSCodeServer\src\repl.jl:276
#
#  [29] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, params::VSCodeServer.NotebookRunCellArguments)
#
#     @ VSCodeServer c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [30] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::Dict{String, Any})
#
#     @ VSCodeServer.JSONRPC c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\packages\JSONRPC\src\typed.jl:67
#
#  [31] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
#
#     @ VSCodeServer c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [32] top-level scope
#
#     @ c:\Users\lexis\.vscode\extensions\julialang.language-julia-1.120.2\scripts\notebook\notebook.jl:35

# %% [markdown]
# Previously, we used `Catalyst` to introduce the model 🐬 $\xrightarrow{\textrm{eat}}$ 🐸 $\xrightarrow{\textrm{eat}}$ 🐜  as:

# %%
using Catalyst
ecomodel = @reaction_network begin
    α₁*(1 - 0.01*🐜 - 0.05*🐸), 🐜 --> 2🐜
    α₂*(1 - 0.1*🐬), 🐜 --> 🐸
    δ₁, 🐜 --> ∅
    δ₂, 🐸 --> 🐬
    δ₃, 🐬 --> ∅
    end α₁ α₂ δ₁ δ₂ δ₃
# Out:
# Model ##ReactionSystem#291
# States (3):
#   🐜(t)
#   🐸(t)
#   🐬(t)
# Parameters (5):
#   α₁
#   α₂
#   δ₁
#   δ₂
#   δ₃

# %% [markdown]
# From the definition of the model as a reaction network, we can turn it into various realizations of a dynamical system, e.g. a system of ODEs (through assumption of mass action kinetics) or a discrete-time stochastic process that can be simulated via Gillespie's algorithm. 👇

# %%
odes = convert(ODESystem, ecomodel)
latexify(odes)
# Out:
# L"\begin{align}
# \frac{d🐜(t)}{dt} =&  - \delta_1 🐜\left( t \right) + \alpha_1 \left( 1 - 0.01 🐜\left( t \right) - 0.05 🐸\left( t \right) \right) 🐜\left( t \right) - \alpha_2 \left( 1 - 0.1 🐬\left( t \right) \right) 🐜\left( t \right) \\
# \frac{d🐸(t)}{dt} =& \alpha_2 \left( 1 - 0.1 🐬\left( t \right) \right) 🐜\left( t \right) - \delta_2 🐸\left( t \right) \\
# \frac{d🐬(t)}{dt} =& \delta_2 🐸\left( t \right) - \delta_3 🐬\left( t \right)
# \end{align}
# "

# %%
## Colors for plotting
cc = ["#835C3B" "#10DA05" "#05E9FF"]

## Parameters [α₁ α₂ δ₁ δ₂ δ₃]
p = (0.2, 0.15, 0.05, 0.15, 0.1)

## Initial conditions
u₀ = [20., 20., 10.]

## time span for simulation 
tspan = (0., 50.)

## create the ODE system
ds = ODEProblem(ecomodel, u₀, tspan, p)

sol = solve(ds, Tsit5())
Plots.plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])

# %%
using 
ds_discrete = DiscreteProblem(ecomodel, [20,20,10], tspan, p)
jump_ds = JumpProblem(ecomodel, ds_discrete, Direct())

sol = solve(jump_ds, SSAStepper())
Plots.plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])
# Out:
# UndefVarError: Direct not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[5]:2
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %% [markdown]
# ## Dynamical systems modeling with MTK

# %% [markdown]
# Now let's redefine the model using `ModelingToolkit (MTK)`. For straightforward simulation or model analyses, this is more or less equivalent to that above using `Catalyst`, but `MTK` packs a lot more under the hood as we'll see...

# %%
using ModelingToolkit
@parameters t α₁ α₂ δ₁ δ₂ δ₃ g₁ g₂ g₃
@variables 🐜(t) 🐸(t) 🐬(t)
D = Differential(t)

eqs = [D(🐜) ~ α₁*🐜*(1 - g₁*🐜 - g₂*🐸) - α₂*🐜*(1-0.1*🐬) - δ₁*🐜,
       D(🐸) ~ α₂*🐜*(1 - g₃*🐬) - δ₂*🐸,
       D(🐬) ~ δ₂*🐸 - δ₃*🐬]
# Out:
# 3-element Vector{Equation}:
#  Differential(t)(🐜(t)) ~ α₁*(1 - g₁*🐜(t) - g₂*🐸(t))*🐜(t) - δ₁*🐜(t) - α₂*(1 - 0.1🐬(t))*🐜(t)
#  Differential(t)(🐸(t)) ~ α₂*(1 - g₃*🐬(t))*🐜(t) - δ₂*🐸(t)
#  Differential(t)(🐬(t)) ~ δ₂*🐸(t) - δ₃*🐬(t)

# %% [markdown]
# Using `MTK` we have defined the ODE model as `odemodel` and can simulate it just as before

# %%
@named ode_model = ODESystem(eqs, t, [🐜,🐸,🐬], [α₁,α₂,δ₁,δ₂,δ₃,g₁,g₂,g₃])

tspan = (0., 50.)

u₀ = [
    🐜=>50., 
    🐸=>10., 
    🐬=>5. ]

p = [
    α₁=>0.2, 
    α₂=>0.3, 
    δ₁=>0.05, 
    δ₂=>0.09, 
    δ₃=>0.1, 
    g₁=>0.01, 
    g₂=>0.05, 
    g₃=>0.08 ]

ds_ode = ODEProblem(ode_model, u₀, tspan, p)
sol = solve(ds_ode, Tsit5())
Plots.plot(sol, lw=4, lc=cc, labels=["Ants" "Frogs" "Fish"])

# %% [markdown]
# For definition of a stochastic differential equation (SDE) model: define the noise model, and then define a `SDESystem`, which we can simulate etc.

# %%
## using multiplicative noise
noiselevel = 0.06
noise_eqs  = [noiselevel*🐜,
              noiselevel*🐸,
              noiselevel*🐬]

@named sde_model = SDESystem(ode_model, noise_eqs)
# Out:
# Model sde_model with 3 equations
# States (3):
#   🐜(t)
#   🐸(t)
#   🐬(t)
# Parameters (8):
#   α₁
#   α₂
#   δ₁
#   δ₂
#   δ₃
#   g₁
# ⋮

# %%
# Define SDE model and simulate
#u₀map  = [🐜=>50., 🐸=>10., 🐬=>5.]


ds_sde = SDEProblem(sde_model, u₀, tspan, p)
sol = solve(ds_sde, SOSRI())
Plots.plot(sol, lw=2, lc=cc, labels=["Ants" "Frogs" "Fish"])
# Out:
# UndefVarError: SOSRI not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:6
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %% [markdown]
# oops! Negative frogs (sometimes)... we'll deal with that later...
# ![frog (1).gif](attachment:14e7f467-7adf-40de-8909-0092b5159b92.gif)

# %%
## move this lower down to below optimization

# %% [markdown]
# ## Sensitivity analysis

# %%
## define conditions for simulation to end
function condition(u,t,integrator) 
  u[1] < 0.0 || u[2] < 0.0 || u[3] < 0.0 || u[4] < 0.0
end
floor_event = DiscreteCallback(condition, terminate!)
# Out:
# DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}(condition, SciMLBase.terminate!, SciMLBase.INITIALIZE_DEFAULT, SciMLBase.FINALIZE_DEFAULT, Bool[1, 1])

# %%
#set up function for sensitivity analysis

p = (α₁, α₂, δ₁, δ₂, δ₃, g₁, g₂, g₃)
ens_model = function (p)
            
    dsfun(ds_ode,i,repeat) = remake(ds_ode; p=p[:,i])
    ds_ensemble = EnsembleProblem(ds_ode, prob_func=dsfun)
    sol = solve(ds_ensemble, DynamicSS(Tsit5()), maxiters=10^8,callback=floor_event, reltol=1e-6, isoutofdomain=(u,p,t)->any(x->x<0,u), EnsembleThreads(), trajectories=size(p,2))
    out = zeros(2,size(p,2))
              
    for i in 1:size(p,2)
        out[1,i] = last(sol[i][1,:])
        out[2,i] = maximum(sol[i][1,:])
    end
    out
end
# Out:
# #1 (generic function with 1 method)

# %%
using SteadyStateDiffEq

odeprob = ODEProblem(ode_model, u₀, tspan, p) 

ens_model = function (p)
    
    dsfun(odeprob,i,repeat) = remake(odeprob; p=p[:,i])
    ds_ensemble = EnsembleProblem(odeprob, prob_func=dsfun)
    sol = solve(ds_ensemble, DynamicSS(Tsit5()), maxiters=10^8, callback=floor_event, reltol=1e-6, isoutofdomain=(u,p,t)->any(x->x<0,u), 
        EnsembleThreads(), trajectories=size(p,2))
    out = zeros(2,size(p,2))
              
    for i in 1:size(p,2)
        out[1,i] = last(sol[i][1,:])
        out[2,i] = maximum(sol[i][1,:])
    end
    out
end

using GlobalSensitivity 


ranges = [[0.,100.],[0.,100.],[0.,100.],[0.,100.],[0.,100.],[0.,100.],[0.,100.]]
Random.seed!(365)

m = gsa(ens_model, Morris(total_num_trajectory=1000,num_trajectory=100), ranges, batch=true)
# Out:
# Incompatible problem+solver pairing.
# For example, this can occur if an ODE solver is passed with an SDEProblem.
# Solvers are only capable of handling specific problem types. Please double
# check that the chosen pairing is capable for handling the given problems.
#
# Problem type: ODEProblem
# Solver type: DynamicSS
# Problem types compatible with the chosen solver: SteadyStateProblem
#
#
# Stacktrace:
#   [1] check_prob_alg_pairing(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float64}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, alg::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/HDcso/src/solve.jl:1042
#   [2] solve_up(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float64}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Vector{Float64}, args::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}; kwargs::Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13"}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/HDcso/src/solve.jl:782
#   [3] solve(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float64}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, args::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}; sensealg::Nothing, u0::Nothing, p::Nothing, kwargs::Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13"}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/HDcso/src/solve.jl:763
#   [4] batch_func(i::Int64, prob::EnsembleProblem{ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, NTuple{8, Num}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, var"#dsfun#12"{Matrix{Float64}}, typeof(SciMLBase.DEFAULT_OUTPUT_FUNC), typeof(SciMLBase.DEFAULT_REDUCTION), Nothing}, alg::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}; kwargs::Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13"}}})
#     @ SciMLBase ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:92
#   [5] (::SciMLBase.var"#503#504"{Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13"}}}, EnsembleProblem{ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, NTuple{8, Num}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, var"#dsfun#12"{Matrix{Float64}}, typeof(SciMLBase.DEFAULT_OUTPUT_FUNC), typeof(SciMLBase.DEFAULT_REDUCTION), Nothing}, DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}})(i::Int64)
#     @ SciMLBase ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:146
#   [6] responsible_map(f::Function, II::UnitRange{Int64})
#     @ SciMLBase ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:139
#   [7] #solve_batch#502
#     @ ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:145 [inlined]
#   [8] #solve_batch#505
#     @ ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:155 [inlined]
#   [9] macro expansion
#     @ ./timing.jl:299 [inlined]
#  [10] __solve(prob::EnsembleProblem{ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, NTuple{8, Num}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, var"#dsfun#12"{Matrix{Float64}}, typeof(SciMLBase.DEFAULT_OUTPUT_FUNC), typeof(SciMLBase.DEFAULT_REDUCTION), Nothing}, alg::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}, ensemblealg::EnsembleThreads; trajectories::Int64, batch_size::Int64, pmap_batch_size::Int64, kwargs::Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13"}}})
#     @ SciMLBase ~/.julia/packages/SciMLBase/BC0Kw/src/ensemble/basic_ensemble_solve.jl:56
#  [11] solve(::EnsembleProblem{ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, NTuple{8, Num}, ODEFunction{true, ModelingToolkit.var"#f#462"{RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x84cd7ece, 0x45b37b97, 0x47faefe0, 0xf715e7be, 0x8a9bcbc9)}, RuntimeGeneratedFunctions.RuntimeGeneratedFunction{(:ˍ₋out, :ˍ₋arg1, :ˍ₋arg2, :t), ModelingToolkit.var"#_RGF_ModTag", ModelingToolkit.var"#_RGF_ModTag", (0x1b8b32c8, 0x3080290f, 0x86ab2fee, 0x07fa372c, 0xbb41bc74)}}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Vector{Symbol}, Symbol, ModelingToolkit.var"#487#generated_observed#469"{Bool, ODESystem, Dict{Any, Any}}, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, var"#dsfun#12"{Matrix{Float64}}, typeof(SciMLBase.DEFAULT_OUTPUT_FUNC), typeof(SciMLBase.DEFAULT_REDUCTION), Nothing}, ::DynamicSS{Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Float64, Float64, Float64}, ::Vararg{Any}; kwargs::Base.Pairs{Symbol, Any, NTuple{5, Symbol}, NamedTuple{(:maxiters, :callback, :reltol, :isoutofdomain, :trajectories), Tuple{Int64, DiscreteCallback{typeof(condition), typeof(terminate!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, Float64, var"#9#13", Int64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/HDcso/src/solve.jl:799
#  [12] (::var"#8#11")(p::Matrix{Float64})
#     @ Main ./In[13]:9
#  [13] gsa(f::var"#8#11", method::Morris, p_range::Vector{Vector{Float64}}; batch::Bool, rng::TaskLocalRNG, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ GlobalSensitivity ~/.julia/packages/GlobalSensitivity/prosr/src/morris_sensitivity.jl:86
#  [14] top-level scope
#     @ In[13]:26
#  [15] eval
#     @ ./boot.jl:373 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1196

# %% [markdown]
# ## Model optimization with `MTK`

# %% [markdown]
# In `MTK` various operations on models are possible to optimize or simplify them. Demonstrated here on `ecomodel` there is not a great deal to optimize, but as models grow in size or complexity, these tools can be invaluable. Let Julia improve your code for you...

# %% [markdown]
# 1. Create a symbolic representation from the numeric ODEProblem

# %%
odesys = modelingtoolkitize(ds_ode) 
ds_with_jac = ODEProblem(odesys, u₀, tspan, jac=true)
# Out:
# ODEProblem with uType Vector{Float64} and tType Float64. In-place: true
# timespan: (0.0, 50.0)
# u0: 3-element Vector{Float64}:
#  50.0
#  10.0
#   5.0

# %% [markdown]
# 2. Create a simplified representation of your model

# %%
simplified_model = structural_simplify(ode_model) 
equations(simplified_model)
# Out:
# 3-element Vector{Equation}:
#  Differential(t)(🐜(t)) ~ α₁*(1 - g₁*🐜(t) - g₂*🐸(t))*🐜(t) - δ₁*🐜(t) - α₂*(1 - 0.1🐬(t))*🐜(t)
#  Differential(t)(🐸(t)) ~ α₂*(1 - g₃*🐬(t))*🐜(t) - δ₂*🐸(t)
#  Differential(t)(🐬(t)) ~ δ₂*🐸(t) - δ₃*🐬(t)

# %%
## Check for correctness 
equations(simplified_model) == equations(ode_model)
# Out:
# true

# %% [markdown]
# ## Finding fixed points via nonlinear solve

# %% [markdown]
# How about finding the fixed points of your model? For nonlinear systems, this is not yet possible in pure Julia, though can be done via `PyCall` (see last year's [example](https://github.com/adamlmaclean/julia-dynsys-resources/blob/main/Dynsys-ecomodel.ipynb)). However, for numerical approximation of the fixed points, there is a growing [family](https://github.com/JuliaNLSolvers) of optimization/nonlinear solvers in Julia.

# %%
using NonlinearSolve

## Define the steady state system
eqs = [0 ~ α₁*🐜*(1 - g₁*🐜 - g₂*🐸) - α₂*🐜 - δ₁*🐜,
       0 ~ α₂*🐜*(1 - g₃*🐬) - δ₂*🐸,
       0 ~ δ₂*🐸 - δ₃*🐬]

@named ns = NonlinearSystem(eqs, [🐜,🐸,🐬], [α₁,α₂,δ₁,δ₂,δ₃,g₁,g₂,g₃])

guess = [🐜 => 10.0,
         🐸 => 10.0,
         🐬 => 10.0]

params = [α₁ => 2.5,
          α₂ => 0.4, 
          δ₁ => 0.8,
          δ₂ => 2.0,
          δ₃ => 5.0,
          g₁ => 0.01,
          g₂ => 1.0,
          g₃ => 0.1]

np = NonlinearProblem(ns, guess, params)
sol = solve(np, NewtonRaphson())
# Out:
# ┌ Warning: `vendor()` is deprecated, use `BLAS.get_config()` and inspect the output instead
# │   caller = (::NonlinearSolve.DefaultLinSolve)(x::Vector{Float64}, A::Matrix{Float64}, b::Vector{Float64}, update_matrix::Bool; tol::Nothing, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}) at utils.jl:124
# └ @ NonlinearSolve /Users/adam/.julia/packages/NonlinearSolve/dsVsp/src/utils.jl:124
# u: 3-element Vector{Float64}:
#  2.5237585102415396
#  0.4947624152068414
#  0.19790496608273653

# %% [markdown]
# ![blender.gif](attachment:801bd4f5-852c-40ff-822e-9c370b0d3a51.gif)
# ## Blending differential equations and ML

# %% [markdown]
# Now, while some of us have _always_ known that differential equations are 😎, that has not always necessarily been the case for our friends in statistical learning. That has changed. With the realization that mixing differential equations with neural networks can improve both [neural networks](https://arxiv.org/abs/1806.07366) and [diffeq models](https://www.sciencedirect.com/science/article/pii/S0021999118307125), a lot of exciting things are happening.

# %% [markdown]
# What does this mean for modeling biological systems? Well, all sorts of [interesting](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1008462) | [applications](https://royalsocietypublishing.org/doi/10.1098/rspa.2019.0800), and the tantalizing possibilty of being able to learn a model's dynamics and topology concurrently. One approach to do this is via universal differential equations (UDEs; named so after the universal approximation theorem oft inherent in the success of ANNs). The [paper](https://arxiv.org/abs/2001.04385) goes into all the details. Here we'll follow the example from the paper, using UDEs to predict the dynamics and learn symbolic terms of the Lokta-Volterra model. We make one significant change to the paper example: rather than fit models to a single trajectory, we fit to multiple realizations from a noisy model. This reflects a situation often faced in biology: we observe heterogeneity between samples (which may have technical as well as biological sources) that we seek to model. By training a model on these batches of noisy trajectories, we are able to improve on the probability of learning the correct model via symbolic regression.

# %%
using Random
rng = Random.seed!(17)

using Lux, MLUtils, OrdinaryDiffEq, DiffEqFlux
using Optimization, OptimizationOptimJL
using IterTools: ncycle
using Printf, Statistics, Plots

output_dir = joinpath(pwd(), "lv_optimization_solve_batch/results/")


## Generate data
function lotka!(du, u, p, t)
    α, β, γ, δ = p
    du[1] = α * u[1] - β * u[2] * u[1]
    du[2] = γ * u[1] * u[2] - δ * u[2]
end

## Define the parameters
t_span = (0.0, 6.0)
u_0_true = [0.44249296, 4.6280594]
odepar = [1.3, 0.9, 0.8, 1.8]
num_species = length(u_0_true)
ode_problem = ODEProblem(lotka!, u_0_true, t_span, odepar)
ode_solution = solve(ode_problem, Vern7(), abstol=1e-12, reltol=1e-12, saveat=0.1)

## Ideal trajectory
u_true = Array(ode_solution)
t = ode_solution.t
t_size = length(t)

## Generate noisy biological samples
sample_size = 100
batch_size = 5
noise_level = 0.05

u_noisy = u_true .+ (noise_level * mean(u_true, dims=2)) .*
                    randn(rng, eltype(u_true), (num_species, t_size, sample_size))
training_data = MLUtils.DataLoader(
    (u_noisy, ), batchsize=batch_size, shuffle=true, rng=rng)

output_prefix = @sprintf("noise_%.2f", noise_level)

## Plot the generated data
ode_data_plot = Plots.plot(ode_solution, color=:black, label=["True data" nothing])
for i = 1:sample_size
    Plots.scatter!(t, transpose(u_noisy[:, :, i]), color=:red, legend=:none)
end
figure_path = joinpath(output_dir, "$(output_prefix)_data.pdf")
savefig(ode_data_plot, figure_path)

# %%
## Define the network
# Gaussian RBF as activation
rbf(x) = exp.(-(x .^ 2))

U_network = Lux.Chain(
    Lux.Dense(2, 5, rbf), Lux.Dense(5, 5, rbf), Lux.Dense(5, 5, rbf),
    Lux.Dense(5, 2)
)
# Get the initial network parameters
nn_params_initial, nn_state = Lux.setup(rng, U_network)

# Define the hybrid model
function ude_dynamics!(du, u, p, t)
    U_pred = U_network(u, p, nn_state)[1]
    du[1] = odepar[1]*u[1] + U_pred[1]
    du[2] = -odepar[4]*u[2] + U_pred[2]
end

function ude_predict(θ, u_0; t_begin=t_span[1], t_end=t_span[2])
    ude_problem = ODEProblem(ude_dynamics!, u_0, (t_begin, t_end), θ)
    solve(ude_problem, Vern7(), saveat=0.1, abstol=1e-6, reltol=1e-6,
          sensealg=ForwardDiffSensitivity())
end

num_intervals = 5
subinterval_size = Int((t_size - 1) / num_intervals)
subinterval_bounds = collect(Int, range(1, t_size, length = num_intervals + 1))

function ude_loss(θ, u_batch)
    total_loss = 1e-3 * sum(abs2, θ) ./ length(θ)

    for i = 1:batch_size
        for j = 1:num_intervals
            left = subinterval_bounds[j]
            right = subinterval_bounds[j + 1]
            u_pred = Array(ude_predict(θ, u_batch[:, left, i], t_begin=t[left],
                                       t_end=t[right]))
            total_loss += sum(abs2, u_pred .- u_batch[:, left:right, i])
        end
    end

    total_loss / batch_size
end

function plot_trained_trajectories(θ, figure_path)
    trained_data_plot = plot(ode_solution, color=:black, label=["True data" nothing])
    for i = 1:sample_size
        u_trained = ude_predict(θ, u_noisy[:, 1, i])
        plot!(t, transpose(u_trained), color=:red, label=false)
    end
    savefig(trained_data_plot, figure_path)
end

function training_callback(θ, l)
    push!(training_losses, l)
    num_iters = length(training_losses)

    if num_iters % 100 == 0
        println("Iteration $(num_iters): loss = $(l)")

        figure_path = @sprintf("%s_training_result_iter_%04d.pdf",
                               output_prefix, num_iters)
        figure_path = joinpath(output_dir, figure_path)
        plot_trained_trajectories(θ, figure_path)
    end

    false
end
# Out:
# training_callback (generic function with 1 method)

# %%
## Train UDE
num_epochs = 100
training_losses = []
opt_function = OptimizationFunction(
    (θ, p, u_batch) -> ude_loss(θ, u_batch), Optimization.AutoZygote())

opt_problem = OptimizationProblem(
    opt_function, Lux.ComponentArray(nn_params_initial))

opt_result = Optimization.solve(
    opt_problem, ADAM(0.1), ncycle(training_data, num_epochs),
    callback=training_callback)

nn_params_trained = opt_result.u

## Plot training loss
training_loss_plot = Plots.plot(training_losses, yaxis=:log, label=false)
figure_path = joinpath(output_dir, "$(output_prefix)_training_losses.pdf")
savefig(training_loss_plot, figure_path)
# Out:
# Iteration 100: loss = 32.8106189687215
# UndefVarError: plot not defined
#
# Stacktrace:
#  [1] plot_trained_trajectories(θ::ComponentVector{Float32}, figure_path::String)
#    @ Main ./In[19]:46
#  [2] training_callback(θ::ComponentVector{Float32}, l::Float64)
#    @ Main ./In[19]:64
#  [3] macro expansion
#    @ ~/.julia/packages/OptimizationFlux/cpWyO/src/OptimizationFlux.jl:34 [inlined]
#  [4] macro expansion
#    @ ~/.julia/packages/Optimization/k85Rf/src/utils.jl:35 [inlined]
#  [5] __solve(prob::OptimizationProblem{true, OptimizationFunction{true, Optimization.AutoZygote, var"#18#19", Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, ComponentArrays.ComponentVector{Float32, Vector{Float32}, Tuple{ComponentArrays.Axis{(layer_1 = ViewAxis(1:15, Axis(weight = ViewAxis(1:10, ShapedAxis((5, 2), NamedTuple())), bias = ViewAxis(11:15, ShapedAxis((5, 1), NamedTuple())))), layer_2 = ViewAxis(16:45, Axis(weight = ViewAxis(1:25, ShapedAxis((5, 5), NamedTuple())), bias = ViewAxis(26:30, ShapedAxis((5, 1), NamedTuple())))), layer_3 = ViewAxis(46:75, Axis(weight = ViewAxis(1:25, ShapedAxis((5, 5), NamedTuple())), bias = ViewAxis(26:30, ShapedAxis((5, 1), NamedTuple())))), layer_4 = ViewAxis(76:87, Axis(weight = ViewAxis(1:10, ShapedAxis((2, 5), NamedTuple())), bias = ViewAxis(11:12, ShapedAxis((2, 1), NamedTuple())))))}}}, SciMLBase.NullParameters, Nothing, Nothing, Nothing, Nothing, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, opt::Adam, data::IterTools.NCycle{DataLoader{Tuple{Array{Float64, 3}}, TaskLocalRNG, Val{nothing}}}; maxiters::Int64, callback::Function, progress::Bool, save_best::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ OptimizationFlux ~/.julia/packages/OptimizationFlux/cpWyO/src/OptimizationFlux.jl:30
#  [6] #solve#514
#    @ ~/.julia/packages/SciMLBase/BC0Kw/src/solve.jl:71 [inlined]
#  [7] top-level scope
#    @ In[24]:10
#  [8] eval
#    @ ./boot.jl:373 [inlined]
#  [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
## Symbolic regression on trained network
using ModelingToolkit, DataDrivenDiffEq

@variables u_sym[1:2]
h_sym = Num[polynomial_basis(u_sym, 5);]
basis_sym = Basis(h_sym, u_sym)
optimizer = STLSQ(Float32.(exp10.(-7:0.1:0)))

for i = 1:5
    sample_idx = Int(sample_size / 5 * i)
    u_trained = ude_predict(nn_params_trained, u_noisy[:, 1, sample_idx])
    symbolic_prob = ContinuousDataDrivenProblem(Array(u_trained), t)
    symbolic_result = solve(sym_reg_problem, basis_sym, optimizer,
                           maxiter=10000, progress=true)

    print("Sample $(sample_idx)")
    symmodel_system = result(symbolic_result)
    symmodel_params = parameters(symbolic_result)
    print(symmodel_system)
    print(symmodel_params)

    sym_reg_plot = plot(symbolic_result)
    figure_path = joinpath(output_dir, "$(output_prefix)_symbolic_regression_$(sample_idx).pdf")
    savefig(sym_reg_plot, figure_path)
end
# Out:
# WARNING: using Flux.frequencies in module DataDrivenDiffEq conflicts with an existing identifier.
# ┌ Info: DataDrivenDiffEq : OccamNet is available.
# └ @ DataDrivenDiffEq /Users/adam/.julia/packages/DataDrivenDiffEq/s9jl3/src/DataDrivenDiffEq.jl:168
# UndefVarError: nn_params_trained not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ ./In[21]:11
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
sym_reg_system
# Out:
# UndefVarError: sym_reg_system not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ :0
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
## Define the model inferred using UDEs
function recovered_dynamics!(du,u, p, t)
    û = sym_reg_result(u, p) # Network prediction
    du[1] = û[1]
    du[2] = û[2]
end

u0 = ode_solution[:,1]
tspan = (0,10)

## Simulate dynamics under the inferred model
estimation_prob = ODEProblem(recovered_dynamics!, u0, tspan, parameters(sym_reg_result))
estimate = solve(estimation_prob, Tsit5(), )

plot(estimate)
# Out:
# UndefVarError: sym_reg_result not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[23]:12
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196
